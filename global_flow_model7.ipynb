# %%
#Final Sankey Graph2
from __future__ import print_function

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, RadioButtons

from IPython.display import clear_output

# %%
from floweaver import *

# %%
dataset = Dataset.from_csv(r'C:\Users\Simon\Dropbox\Thesis Al recycling\extended sankey model7.csv')

# %%
dataset._flows.head()
# Out:
#     source target series        1950        1951        1952        1953  \
# 0  primary   1000   1000  358.183056  418.046352  475.773199  573.935146
# 1  primary   2000   2000    1.655273    1.975782    2.276299    2.774816
# 2  primary   3000   3000  137.010511  156.330089  176.698758  217.133360
# 3  primary   4000   4000    3.589280    4.272004    4.919233    6.002269
# 4  primary   5000   5000  294.853564  333.357467  372.250314  472.747679
#
#          1954        1955        1956  ...          2031          2032  \
# 0  666.596875  724.022024  792.921721  ...  21850.364550  22398.062390
# 1    3.220728    3.469917    3.790160  ...    793.478271    824.493233
# 2  248.618328  269.554512  291.152739  ...  10811.222410  11130.402800
# 3    6.963742    7.507912    8.180730  ...    466.935172    483.802158
# 4  531.022498  575.709518  623.001078  ...  27030.842330  27808.862100
#
#            2033          2034          2035          2036          2037  \
# ...

# %%
nodes = {
    'primary': ProcessGroup(['primary']),
    'recycled': ProcessGroup(['recycled']),
    
    '1000': ProcessGroup(['1000']),
    '2000': ProcessGroup(['2000']),
    '3000': ProcessGroup(['3000']),
    '4000': ProcessGroup(['4000']),
    '5000': ProcessGroup(['5000']),
    '6000': ProcessGroup(['6000']),
    '7000': ProcessGroup(['7000']),
    '8000': ProcessGroup(['8000']),
    'cast': ProcessGroup(['cast']),
    'cans recycled': ProcessGroup(['cans recycled'], title=''),
    'scrap surplus': ProcessGroup(['scrap surplus']),
    
    'building': ProcessGroup(['building']),
    'auto': ProcessGroup(['auto']),
    'aerospace': ProcessGroup(['aerospace']),
    'transport': ProcessGroup(['transport']),
    'cans': ProcessGroup(['cans']),
    'foil': ProcessGroup(['foil']),
    'machinery': ProcessGroup(['machinery']),
    'cable': ProcessGroup(['cable']),
    'electrical': ProcessGroup(['electrical']),
    'consumer durables': ProcessGroup(['c durables']),
    'other': ProcessGroup(['other']),
    'destructive': ProcessGroup(['destructive']),
    #'cans collected': ProcessGroup(['cans collected'], title=''),
    
    'building use': ProcessGroup(['building use']),
    'auto use': ProcessGroup(['auto use']),
    'aerospace use': ProcessGroup(['aerospace use']),
    'transport use': ProcessGroup(['transport use']),
    'cans use': ProcessGroup(['cans use']),
    'foil use': ProcessGroup(['foil use']),
    'machinery use': ProcessGroup(['machinery use']),
    'cable use': ProcessGroup(['cable use']),
    'electrical use': ProcessGroup(['electrical use']),
    'consumer durables use': ProcessGroup(['c durables use']),
    'other use': ProcessGroup(['other use']),
    'destructive use': ProcessGroup(['destructive use']),
    'new scrap': ProcessGroup(['new scrap']),
    
    'collected': ProcessGroup(['collected']),
    'not collected': ProcessGroup(['not collected']),
    'collected cans': ProcessGroup(['collected cans']),
    
    
    'w1': Waypoint(direction='L', title=''),
    'w2': Waypoint(direction='L', title=''),
    #'w3': Waypoint(direction='L', title=''),
    
}

# %%
ordering = [
    [['primary', 'recycled'], [], [], [], [], [], [], [], [], [], [], []],
    [['1000', '2000', '3000', '4000', '5000', '6000', '7000', '8000', 'cast', 'scrap surplus', 'cans recycled'], [], []],
    [['building', 'auto', 'aerospace', 'transport', 'cans', 'foil', 'machinery', 'cable', 'electrical', 'consumer durables', 'other', 'destructive'], ['w1']],
    [['building use', 'auto use', 'aerospace use', 'transport use', 'cans use', 'foil use', 'machinery use', 'cable use', 'electrical use', 'consumer durables use', 'other use', 'destructive use'], ['new scrap', 'w2']],
    [['not collected', 'collected','collected cans'], [], [], [], [], [], [], [], [], [], []],
]

# %%
bundles = [
    Bundle('primary', '1000'),
    Bundle('primary', '2000'),
    Bundle('primary', '3000'),
    Bundle('primary', '4000'),
    Bundle('primary', '5000'),
    Bundle('primary', '6000'),
    Bundle('primary', '7000'),
    Bundle('primary', '8000'),
    Bundle('primary', 'cast'),
    
    Bundle('recycled', '1000'),
    Bundle('recycled', '2000'),
    Bundle('recycled', '3000'),
    Bundle('recycled', '4000'),
    Bundle('recycled', '5000'),
    Bundle('recycled', '6000'),
    Bundle('recycled', '7000'),
    Bundle('recycled', '8000'),
    Bundle('recycled', 'cast'),
    Bundle('recycled', 'cans recycled'),
    Bundle('recycled', 'scrap surplus'),
    
    Bundle('1000', 'building'),
    Bundle('1000', 'auto'),
    Bundle('1000', 'aerospace'),
    Bundle('1000', 'transport'),
    Bundle('1000', 'cans'),
    Bundle('1000', 'foil'),
    Bundle('1000', 'machinery'),
    Bundle('1000', 'cable'),
    Bundle('1000', 'electrical'),
    Bundle('1000', 'consumer durables'),
    Bundle('1000', 'other'),
    Bundle('1000', 'destructive'),
    
    Bundle('2000', 'building'),
    Bundle('2000', 'auto'),
    Bundle('2000', 'aerospace'),
    Bundle('2000', 'transport'),
    Bundle('2000', 'cans'),
    Bundle('2000', 'foil'),
    Bundle('2000', 'machinery'),
    Bundle('2000', 'cable'),
    Bundle('2000', 'electrical'),
    Bundle('2000', 'consumer durables'),
    Bundle('2000', 'other'),
    Bundle('2000', 'destructive'),
    
    Bundle('3000', 'building'),
    Bundle('3000', 'auto'),
    Bundle('3000', 'aerospace'),
    Bundle('3000', 'transport'),
    Bundle('3000', 'cans'),
    Bundle('3000', 'foil'),
    Bundle('3000', 'machinery'),
    Bundle('3000', 'cable'),
    Bundle('3000', 'electrical'),
    Bundle('3000', 'consumer durables'),
    Bundle('3000', 'other'),
    Bundle('3000', 'destructive'),
    
    Bundle('4000', 'building'),
    Bundle('4000', 'auto'),
    Bundle('4000', 'aerospace'),
    Bundle('4000', 'transport'),
    Bundle('4000', 'cans'),
    Bundle('4000', 'foil'),
    Bundle('4000', 'machinery'),
    Bundle('4000', 'cable'),
    Bundle('4000', 'electrical'),
    Bundle('4000', 'consumer durables'),
    Bundle('4000', 'other'),
    Bundle('4000', 'destructive'),
    
    Bundle('5000', 'building'),
    Bundle('5000', 'auto'),
    Bundle('5000', 'aerospace'),
    Bundle('5000', 'transport'),
    Bundle('5000', 'cans'),
    Bundle('5000', 'foil'),
    Bundle('5000', 'machinery'),
    Bundle('5000', 'cable'),
    Bundle('5000', 'electrical'),
    Bundle('5000', 'consumer durables'),
    Bundle('5000', 'other'),
    Bundle('5000', 'destructive'),
    
    Bundle('6000', 'building'),
    Bundle('6000', 'auto'),
    Bundle('6000', 'aerospace'),
    Bundle('6000', 'transport'),
    Bundle('6000', 'cans'),
    Bundle('6000', 'foil'),
    Bundle('6000', 'machinery'),
    Bundle('6000', 'cable'),
    Bundle('6000', 'electrical'),
    Bundle('6000', 'consumer durables'),
    Bundle('6000', 'other'),
    Bundle('6000', 'destructive'),
    
    Bundle('7000', 'building'),
    Bundle('7000', 'auto'),
    Bundle('7000', 'aerospace'),
    Bundle('7000', 'transport'),
    Bundle('7000', 'cans'),
    Bundle('7000', 'foil'),
    Bundle('7000', 'machinery'),
    Bundle('7000', 'cable'),
    Bundle('7000', 'electrical'),
    Bundle('7000', 'consumer durables'),
    Bundle('7000', 'other'),
    Bundle('7000', 'destructive'),
    
    Bundle('8000', 'building'),
    Bundle('8000', 'auto'),
    Bundle('8000', 'aerospace'),
    Bundle('8000', 'transport'),
    Bundle('8000', 'cans'),
    Bundle('8000', 'foil'),
    Bundle('8000', 'machinery'),
    Bundle('8000', 'cable'),
    Bundle('8000', 'electrical'),
    Bundle('8000', 'consumer durables'),
    Bundle('8000', 'other'),
    Bundle('8000', 'destructive'),
    
    Bundle('cast', 'building'),
    Bundle('cast', 'auto'),
    Bundle('cast', 'aerospace'),
    Bundle('cast', 'transport'),
    Bundle('cast', 'cans'),
    Bundle('cast', 'foil'),
    Bundle('cast', 'machinery'),
    Bundle('cast', 'cable'),
    Bundle('cast', 'electrical'),
    Bundle('cast', 'consumer durables'),
    Bundle('cast', 'other'),
    Bundle('cast', 'destructive'),
    
    Bundle('cans recycled', 'cans'),
    
    Bundle('building', 'building use'),
    Bundle('auto', 'auto use'),
    Bundle('aerospace', 'aerospace use'),
    Bundle('transport', 'transport use'),
    Bundle('cans', 'cans use'),
    Bundle('foil', 'foil use'),
    Bundle('machinery', 'machinery use'),
    Bundle('cable', 'cable use'),
    Bundle('electrical', 'electrical use'),
    Bundle('consumer durables', 'consumer durables use'),
    Bundle('other', 'other use'),
    Bundle('destructive', 'destructive use'),
    
    Bundle('building', 'new scrap'),
    Bundle('auto', 'new scrap'),
    Bundle('aerospace', 'new scrap'),
    Bundle('transport', 'new scrap'),
    Bundle('cans', 'new scrap'),
    Bundle('foil', 'new scrap'),
    Bundle('machinery', 'new scrap'),
    Bundle('cable', 'new scrap'),
    Bundle('electrical', 'new scrap'),
    Bundle('consumer durables', 'new scrap'),
    Bundle('other', 'new scrap'),
    Bundle('destructive', 'new scrap'),
    
    Bundle('building use', 'collected'),
    Bundle('auto use', 'collected'),
    Bundle('aerospace use', 'collected'),
    Bundle('transport use', 'collected'),
    Bundle('cans use', 'collected cans'),
    Bundle('foil use', 'collected'),
    Bundle('machinery use', 'collected'),
    Bundle('cable use', 'collected'),
    Bundle('electrical use', 'collected'),
    Bundle('consumer durables use', 'collected'),
    Bundle('other use', 'collected'),
    Bundle('destructive use', 'collected'),
    
    Bundle('building use', 'not collected'),
    Bundle('auto use', 'not collected'),
    Bundle('aerospace use', 'not collected'),
    Bundle('transport use', 'not collected'),
    Bundle('cans use', 'not collected'),
    Bundle('foil use', 'not collected'),
    Bundle('machinery use', 'not collected'),
    Bundle('cable use', 'not collected'),
    Bundle('electrical use', 'not collected'),
    Bundle('consumer durables use', 'not collected'),
    Bundle('other use', 'not collected'),
    Bundle('destructive use', 'not collected'),
    
    #Bundle('collected cans', 'cans collected'),
    
    #Bundle('cans collected', 'recycled'),
    Bundle('collected cans', 'recycled'),
    Bundle('collected', 'recycled', waypoints = ['w2', 'w1']),
    Bundle('new scrap', 'recycled')
    
    
    #Bundle('collected', 'recycled', waypoints=['w3']),
    #Bundle('new scrap', 'recycled', waypoints=['w3']),
    #Bundle('collected cans', 'recycled cans', waypoints=['w2']),
    #Bundle('collected cable', 'recycled cable', waypoints=['w1']),
]

# %%
series_partition = Partition.Simple('series', ['1000', '2000', '3000', '4000', '5000', '6000', '7000', '8000', 'cast', 'mixed', 'recycled cans', 'new scrap', 'old scrap'])
palette = {'1000': 'maroon', '2000': 'red', '3000': 'gold', '4000': 'yellowgreen', '5000': 'aqua', '6000': 'navy', '7000': 'purple', '8000': 'magenta', 'cast': 'wheat', 'mixed': 'grey', 'recycled cans': 'darkgreen', 'new scrap': 'peru', 'old scrap': 'saddlebrown'}

sdd = SankeyDefinition(nodes, bundles, ordering, flow_partition=series_partition)

int_range = widgets.IntSlider(value=2020,min=1950,max=2040,step=1)
output2 = widgets.Output()

display(int_range, output2)

def on_value_change(x):
    with output2:
        number = x['new']
        clear_output()
        p = weave(sdd, dataset, measures='{}'.format(number), palette=palette).to_widget(width=1500, height=1050, margins=dict(left=100, right=100))
        display(p)
        
int_range.observe(on_value_change, 'value')
# Out:
# IntSlider(value=2020, max=2040, min=1950)
# Output()
